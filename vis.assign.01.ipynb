# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.
ans:
A1: Matplotlib is a Python library for creating various data visualizations like charts and graphs. 

It's used because:

* **Easy & powerful:** Makes simple plots easy and complex ones possible.
* **Flexible:** Customize styles, layouts, and export formats.
* **Interactive:** Create graphs that zoom, pan, and update.

Five Pyplot plot types:

1. **Line:** Shows trends over time or data categories.
2. **Bar:** Compares values across categories.
3. **Scatter:** Shows relationships between two variables.
4. **Histogram:** Distribution of data points in ranges.
5. **Boxplot:** Summarizes data distribution (Q1, Q3, outliers).





Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
ans:



A scatter plot is a type of graph that uses dots to represent individual data points. 
Each point's position on the horizontal and vertical axes corresponds to the values of two different variables. 
By looking at the pattern of the dots, you can quickly see how the two variables are related.

import matplotlib.pyplot as plt

import numpy as np
np.random.seed(3)

x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x)


plt.scatter(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is title")
plt.show()

(Note: Also add title, xlabel, and ylabel to the plot.)







Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
                         import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
                         
                         
                         
ans:
                         
  import matplotlib.pyplot as plt

# Example data
x = [0,1, 2, 3, 4, 5]
y1 = [0, 100, 200, 300, 400,500]
y2 = [50, 20, 40, 20, 60, 70]
y3 = [10, 20, 30, 40, 50, 60]
y4 = [200, 350, 250, 550, 450, 150]

# Create the figure and subplots
fig, axs = plt.subplots(2, 2)

# Plot the data on each subplot
axs[0, 0].plot(x, y1, label="Line 1")
axs[0, 1].plot(x, y2, label="Line 2")
axs[1, 0].plot(x, y3, label="Line 3")
axs[1, 1].plot(x, y4, label="Line 4")

# Add labels and title
axs[0, 0].set_title("Subplot 1")
axs[0, 1].set_title("Subplot 2")
axs[1, 0].set_title("Subplot 3")
axs[1, 1].set_title("Subplot 4")
axs[0, 0].set_ylabel("Y-axis")
axs[0, 0].set_xlabel("X-axis")

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()                       
                         
                         
                         
                         
                         
                         
                         
                         
                         
                         
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
ans:
A bar plot, also knon as a bar chart, is a type of graph that represents categorical data using rectangular bars with heights or lengths 
proportional to the values they represent. It's a simple and effective way to visually compare different categories.

                         
                         
 Bar plots are a versatile tool that can be used in a variety of situations. They are particularly useful when you want to:

Compare different categories of data.
Show the distribution of data within a category.
Highlight the highest or lowest values in a dataset.
Make data easier to understand for a general audience.                        
                         
                         
    import matplotlib.pyplot as plt                     
    import numpy as np                      
    x=["apple","Microsoft","Google","AMD"]                     
    y=[3000,8000,1000,10000]                    
    plt.barh(x,y)                   
                         
                         
                         
                         





Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
ans:
